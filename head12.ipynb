# %%
from scipy.io import loadmat
import pandas as pd

# %%
fase1 = loadmat("TTL project data/VKL DMP/VKL-DMP-06/2021-Støren-RawData/fase1/h12_1.mat")
fase2 = loadmat("TTL project data/VKL DMP/VKL-DMP-06/2021-Støren-RawData/fase2/h12_2.mat")
fase3 = loadmat("TTL project data/VKL DMP/VKL-DMP-06/2021-Støren-RawData/fase3/h12_3.mat")
fase4 = loadmat("TTL project data/VKL DMP/VKL-DMP-06/2021-Støren-RawData/fase4/h12_4.mat")
fase5 = loadmat("TTL project data/VKL DMP/VKL-DMP-06/2021-Støren-RawData/fase5/h12_5.mat")
fase6 = loadmat("TTL project data/VKL DMP/VKL-DMP-06/2021-Støren-RawData/fase6/h12_6.mat")
fase7 = loadmat("TTL project data/VKL DMP/VKL-DMP-06/2021-Støren-RawData/fase7/h12_7.mat")
fase8 = loadmat("TTL project data/VKL DMP/VKL-DMP-06/2021-Støren-RawData/fase8/h12_8.mat")
fase9 = loadmat("TTL project data/VKL DMP/VKL-DMP-06/2021-Støren-RawData/fase9/h12_9.mat")
fase10 = loadmat("TTL project data/VKL DMP/VKL-DMP-06/2021-Støren-RawData/fase10/h12_10.mat")
fase11 = loadmat("TTL project data/VKL DMP/VKL-DMP-06/2021-Støren-RawData/fase11/h12_11.mat")

# %%
measure_f1 = pd.DataFrame(fase1['Measurements'][0])
measure_f2 = pd.DataFrame(fase2['Measurements'][0])
measure_f3 = pd.DataFrame(fase3['Measurements'][0])
measure_f4 = pd.DataFrame(fase4['Measurements'][0])
measure_f5 = pd.DataFrame(fase5['Measurements'][0])
measure_f6 = pd.DataFrame(fase6['Measurements'][0])
measure_f7 = pd.DataFrame(fase7['Measurements'][0])
measure_f8 = pd.DataFrame(fase8['Measurements'][0])
measure_f9 = pd.DataFrame(fase9['Measurements'][0])
measure_f10 = pd.DataFrame(fase10['Measurements'][0])
measure_f11 = pd.DataFrame(fase11['Measurements'][0])

# %%
a=measure_f1.drop(['name', 'properties'],axis=1)
b=measure_f2.drop(['name', 'properties'],axis=1)
c=measure_f3.drop(['name', 'properties'],axis=1)
d=measure_f4.drop(['name', 'properties'],axis=1)
e=measure_f5.drop(['name', 'properties'],axis=1)
f=measure_f6.drop(['name', 'properties'],axis=1)
g=measure_f7.drop(['name', 'properties'],axis=1)
h=measure_f8.drop(['name', 'properties'],axis=1)
i=measure_f9.drop(['name', 'properties'],axis=1)
j=measure_f10.drop(['name', 'properties'],axis=1)
k=measure_f11.drop(['name', 'properties'],axis=1)

# %%
col = a.columns
col
# Out:
# Index(['PIN1', 'PTC', 'PDT1', 'PDT2', 'PGV1', 'PGV2', 'PGV3', 'PDT3', 'PDT4',
#        'Patm', 'WTmp', 'rpm', 'Speed', 'Flow', 'Thrust', 'GenTorque',
#        'FricTorque', 'Pin', 'Pdiff', 'GV', 'AGV', 'ATB1', 'ATB2'],
#       dtype='object')

# %%
ranges = [a,b,c,d,e,f,g,h,i,j,k]

# %%
count = 0
for index in col:
    for r in ranges:
        c=r[index]
        d=c[0]
        e=d[0][0][0]
        f=e.flatten()
        print(f)
# Out:
# [0.00149937 0.00149897 0.00149929 ... 0.00151169 0.00151204 0.00151073]
# [0.00151182 0.00151168 0.0015116  ... 0.00151754 0.00151689 0.00151744]
# [0.00147474 0.00147522 0.00147421 ... 0.00146827 0.00146871 0.0014688 ]
# [0.00148508 0.001485   0.00148533 ... 0.00147727 0.00147819 0.00147894]
# [0.00150337 0.00150326 0.00150227 ... 0.00150686 0.00150664 0.00150747]
# [0.00147886 0.00148008 0.00148009 ... 0.00149323 0.00149408 0.00149428]
# [0.0014954  0.00149613 0.001495   ... 0.00149878 0.0014989  0.00149909]
# [0.00149684 0.00149673 0.00149545 ... 0.00149174 0.00149199 0.00149139]
# [0.0015035  0.00150394 0.00150389 ... 0.00149846 0.00149829 0.00149728]
# [0.00149683 0.00149665 0.00149637 ... 0.00149567 0.00149595 0.0014948 ]
# [0.00149273 0.00149285 0.0014935  ... 0.00149359 0.00149474 0.00149486]
# [0.0007303  0.00072989 0.00072792 ... 0.00072742 0.00072929 0.00072824]
# [0.00072441 0.00072304 0.00072212 ... 0.00072464 0.00072503 0.0007241 ]
# ...
